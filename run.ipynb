# %%
import pandas as pd
df = pd.read_excel('rep/esf-14000321.xlsx')
df
# Out:
#         شماره پايانه  سريال پايانه  تاريخ نصب پايانه    وضعيت پايانه  \
# 0         33001115.0  04120149            13831216.0    جمع آوری شده
# 1         33001141.0  04120175            13831205.0    جمع آوری شده
# 2         33017405.0  05070110            13840719.0    جمع آوری شده
# 3         33002444.0  04121669            13840110.0     از رده خارج
# 4         33006697.0  05010529            13840303.0    جمع آوری شده
# ...              ...           ...               ...             ...
# 183580    98532290.0  77700191937         13991027.0  راه اندازي شده
# 183581    98556859.0  77700769434         13991030.0  راه اندازي شده
# 183582    98588583.0  121109060           13991225.0  راه اندازي شده
# 183583    98613915.0  0                   14000229.0  راه اندازي شده
# 183584           NaN           NaN               NaN             NaN
#
#                  نام فروشگاه                          صنف  \
# 0                رستوران صفه                   مواد غذايي
# ...
